# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('contacts-CDM.csv')

# %%
df
# Out:
#                          First Name Middle Name Last Name  \
# 0                            -Akian         NaN     Mardi
# 1                          -Budiman         NaN       Ace
# 2                       -Ng Juliana         NaN       ami
# 3                             -Rina         NaN    Ramani
# 4      -yung pin cell - ho yung pin         NaN    hendra
# ...                             ...         ...       ...
# 2332                            NaN         NaN       NaN
# 2333                            NaN         NaN       NaN
# 2334                            NaN         NaN       NaN
# 2335                            NaN         NaN       NaN
# 2336                            NaN         NaN       NaN
#
#       Phonetic First Name  Phonetic Middle Name  Phonetic Last Name  \
# 0                     NaN                   NaN                 NaN
# 1                     NaN                   NaN                 NaN
# ...
